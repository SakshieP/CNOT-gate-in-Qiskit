# %%
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, execute, Aer, IBMQ
from qiskit.visualization import plot_histogram
IBMQ.save_account("3bad7f81ce368b605bafb1b55816d15736f2cf7b95d53584437580099ff9d45b564f4e6043ed3201a4c25d441e41b18373702f9c470848717e2e8dc800c1c47c")
# Out:
# configrc.store_credentials:WARNING:2021-03-20 14:47:33,499: Credentials already present. Set overwrite=True to overwrite.

# %%
qreg = QuantumRegister(2, 'q')
creg = ClassicalRegister(2, 'c')

circuit = QuantumCircuit(qreg, creg)

# %%
circuit.h(qreg[0])
circuit.cx(qreg[0], qreg[1])
circuit.measure(range(2), range(2))
circuit.draw()
# Out:
#      ┌───┐     ┌─┐┌───┐     ┌─┐┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├┤ H ├──■──┤M├┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘└┬─┬┘┌─┴─┐└╥┘└┬─┬┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫──┤M├─┤ X ├─╫──┤M├─┤ X ├─╫─┤M├
#           └───┘ ║  └╥┘ └───┘ ║  └╥┘ └───┘ ║ └╥┘
# c: 2/═══════════╩═══╩════════╩═══╩════════╩══╩═
#                 0   1        0   1        0  1

# %%
backend = Aer.get_backend('qasm_simulator')
counts = execute(circuit, backend).result().get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'00': 275, '01': 257, '10': 256, '11': 236}

# %%
backend = Aer.get_backend('qasm_simulator')
counts = execute(circuit, backend).result().get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'00': 275, '01': 257, '10': 256, '11': 236}
